# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

file_route="csv_files_2/data/temp_data.csv"
file_path=Path(file_route)

df_temperature=pd.read_csv(file_path)

for i,column in enumerate(df_temperature.columns):
    print(f"{i} -> {column}")
# Out:
# 0 -> Registro temporal para frecuencia de muestreo cada 12 Hrs min
# 1 ->  Temperatura_Celsius
# 2 -> Humedad_relativa

# %%
df_temp=df_temperature[" Temperatura_Celsius"]
df_temp.plot(title="Temperature",grid=1)
plt.show()
