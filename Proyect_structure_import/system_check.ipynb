# %%
import sys
import pandas as pd
import numpy
import matplotlib.pyplot

print(len(sys.modules))

for mod in sys.modules:
    print(mod)
# Out:
# 1480
# sys
# builtins
# _frozen_importlib
# _imp
# _thread
# _warnings
# _weakref
# winreg
# _io
# marshal
# nt
# _frozen_importlib_external
# time
# zipimport
# _codecs
# codecs
# encodings.aliases
# encodings
# encodings.utf_8
# _signal
# _abc
# abc
# io
# __main__
# _stat
# stat
# _collections_abc
# genericpath
# _winapi
# ntpath
# os.path
# os
# _sitebuiltins
# encodings.cp1252
# types
# importlib._bootstrap
# importlib._bootstrap_external
# warnings
# importlib
# importlib._abc
# itertools
# keyword
# _operator
# operator
# reprlib
# _collections
# collections
# _functools
# functools
# contextlib
# importlib.util
# importlib.machinery
# mpl_toolkits
# pywin32_system32
# pywin32_bootstrap
# _distutils_hack
# site
# runpy
# enum
# _sre
# re._constants
# re._parser
# re._casefix
# re._compiler
# copyreg
# re
# collections.abc
# _typing
# typing.io
# typing.re
# typing
# ipykernel._version
# _json
# json.scanner
# json.decoder
# json.encoder
# json
# errno
# _locale
# locale
# ...

# %%
for cache in sys.path_importer_cache:
    print(cache)
# Out:
# c:\Users\Automation\AppData\Local\Programs\Python\Python311\python311.zip
# c:\Users\Automation\AppData\Local\Programs\Python\Python311\DLLs
# c:\Users\Automation\AppData\Local\Programs\Python\Python311\Lib
# c:\Users\Automation\AppData\Local\Programs\Python\Python311\Lib\encodings
# c:\Users\Automation\AppData\Local\Programs\Python\Python311\Lib\importlib
# C:\Users\Automation\AppData\Roaming\Python\Python311\site-packages
# c:\Users\Automation\AppData\Local\Programs\Python\Python311
# C:\Users\Automation\AppData\Roaming\Python\Python311\site-packages\win32
# C:\Users\Automation\AppData\Roaming\Python\Python311\site-packages\win32\lib
# C:\Users\Automation\AppData\Roaming\Python\Python311\site-packages\Pythonwin
# c:\Users\Automation\AppData\Local\Programs\Python\Python311\Lib\site-packages
# c:\Users\Automation\Documents\python\Proyect_structure_import
# C:\Users\Automation\AppData\Roaming\Python\Python311\site-packages\ipykernel
# ...

# %%
"""Some of the most pernicious
misconceptions about Python revolve
around its nuances regarding variables
and data types. Misunderstandings
related to this one topic cause countless
frustrating bugs, and this is unfortunate.
Python’s way of handling variables is at
the core of its power and versatility. If
you understand this, everything else
falls into place."""

# %%
nums = [1,2,3,4]
nums2 = nums
nums2.append(5)
new = nums + [8]
print(f"nums {id(nums)} - {nums}")
print(f"nums2 {id(nums2)} - {nums2}")
print(f"new {id(new)} - {new}")
# Out:
# nums 2305573771712 - [1, 2, 3, 4, 5]
# nums2 2305573771712 - [1, 2, 3, 4, 5]
# new 2305581498112 - [1, 2, 3, 4, 5, 8]

# %%
work_list = [1,2,3,4,5]
member = work_list[1]
work_list[1] = 1
print(member)
print(work_list)
# Out:
# 2
# [1, 1, 3, 4, 5]

# %%
# assignation practice
x = 43
y = x
z = y
x = x + 1
print(x)
print(y)
print(z is y)
# Out:
# 44
# 43
# True

# %%
text_string = "Hola mundo"
if isinstance(text_string,str):
    print("String asignado")
# Out:
# String asignado
